# %%
import os
import sys
import pandas as pd
import numpy as np

if os.getcwd() != '/home/jonah/Desktop/SPARCED/test':
    os.chdir('/home/jonah/Desktop/SPARCED/test')
else:
    print(os.getcwd()) 
cd = os.getcwd()
wd = os.path.dirname(cd)
sys.path.append(os.path.join(wd, 'toolbox'))
sys.path.append(os.path.join(wd, 'bin'))
print(sys.path)

from lineage_tracing import *
# Out:
# /home/jonah/Desktop/SPARCED/test
# ['/home/jonah/Desktop/SPARCED/test', '/home/jonah/anaconda3/envs/sparced/lib/python311.zip', '/home/jonah/anaconda3/envs/sparced/lib/python3.11', '/home/jonah/anaconda3/envs/sparced/lib/python3.11/lib-dynload', '', '/home/jonah/anaconda3/envs/sparced/lib/python3.11/site-packages', '/home/jonah/Desktop/SPARCED/toolbox', '/home/jonah/Desktop/SPARCED/bin']

# %%
exp_title = 'in_silico_drs'
output_main = os.path.join(wd,'output', exp_title)

# %%
trame0_01 = drs_dict(output_main,'trame',0,1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 trame0_01 = drs_dict(output_main,'trame',0,1)
#
# File ~/Desktop/SPARCED/toolbox/lineage_tracing.py:54, in drs_dict.__init__(self, main, drug, rep, dose_level)
#      52 self.doses.sort()
#      53 ###JRHUGGI: The above lines seem very convoluted. I suggest you use a dictionary to store all information, such as a JSON or XML dictionary file.###
# ---> 54 self.path_dose = os.path.join(self.path_rep,str(drug)+'_EC_'+str(self.doses[dose_level]))
#      56 dose_files = os.listdir(self.path_dose)
#      57 self.results = {}
#
# IndexError: list index out of range

# %%
palbo1_0.dendro()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# ...

# %%
palbo1_0.lin_tree_solo(1)
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...
